# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de fotocasa, el cual es uno de los sitios mas populares de bienes raíces en España. Por favor no hagas estos (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa mas cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!
#
# Let's start with precisely that question... Good luck!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

# this CSV file contains semicolons instead of comas as separator
ds = pd.read_csv('assets/real_estate.csv', sep=';')
ds
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa mas cara en el todo el dataset? (★☆☆)
#
# Imprime la direccion y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address General Street Nº5 is the most expensive and its price is 5000000 USD`

# %%
series_df = ds.columns
print(series_df)
# Out:
# Index(['Unnamed: 0', 'id_realEstates', 'isNew', 'realEstate_name',
#        'phone_realEstate', 'url_inmueble', 'rooms', 'bathrooms', 'surface',
#        'price', 'date', 'description', 'address', 'country', 'level1',
#        'level2', 'level3', 'level4', 'level5', 'level6', 'level7', 'level8',
#        'upperLevel', 'countryId', 'level1Id', 'level2Id', 'level3Id',
#        'level4Id', 'level5Id', 'level6Id', 'level7Id', 'level8Id', 'accuracy',
#        'latitude', 'longitude', 'zipCode', 'customZone'],
#       dtype='object')

# %%
# TODO

casa_cara = ds["price"].max()
id_casa_cara = ds["price"].idxmax()
dire_casa_cara = ds.loc[id_casa_cara,"address"]



print(f"La casa más cara de la Base de Datos tiene dirección en {dire_casa_cara}, con un valor de {casa_cara} $")
# Out:
# La casa más cara de la Base de Datos tiene dirección en El Escorial, con un valor de 8500000 $

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa mas barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `The house with address Concrete Street Nº1 is the cheapest and its price is 12000 USD`

# %%
# TODO

casa_mas_barata = ds["price"].min()
casa_mas_barata_id = ds["price"].idxmin()
direccion= ds.loc[casa_mas_barata_id, "address"]


print("The house with address", direccion,"is the cheapest and its price is", casa_mas_barata, "USD")
# Out:
# The house with address Parla is the cheapest and its price is 0 USD

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa mas grande y la mas pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el area de las casas seleccionadas. Por ejemplo:
#
# `The bigger house is located on Yukka Street Nº10 and its surface is 5000 meters`
#
# `The smaller house is located on County Road 1 N and its surface is 200 meters`

# %%
# TODO

casa_mas_grande = ds["surface"].max()
casa_mas_grande_id = ds["surface"].idxmax()
direccion_casa_grande = ds.loc[casa_mas_grande_id, "address"]
print("The bigger house is located in", direccion_casa_grande, "and its surface is", casa_mas_grande, "meters")

casa_mas_chica = ds["surface"].min()
casa_mas_chica_id = ds["surface"].idxmin()
direccion_casa_chica = ds.loc[casa_mas_chica_id, "address"]
print("The smaller house is locates on", direccion_casa_chica, "and its surface is", casa_mas_chica, "meters")
# Out:
# The bigger house is located in Sevilla la Nueva and its surface is 249000.0 meters
# The smaller house is locates on Calle Amparo,  Madrid Capital and its surface is 15.0 meters

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3,...`

# %%
# TODO

poblaciones = ds["level5"].unique()
poblaciones_abc =sorted(poblaciones)

print(poblaciones_abc)
# Out:
# [' Madrid Capital', 'Ajalvir', 'Alcalá de Henares', 'Alcobendas', 'Alcorcón', 'Aldea del Fresno', 'Algete', 'Alpedrete', 'Ambite', 'Anchuelo', 'Aranjuez', 'Arganda del Rey', 'Arroyomolinos (Madrid)', 'Batres', 'Becerril de la Sierra', 'Belmonte de Tajo', 'Boadilla del Monte', 'Braojos', 'Brea de Tajo', 'Brunete', 'Buitrago del Lozoya', 'Bustarviejo', 'Cabanillas de la Sierra', 'Cadalso de los Vidrios', 'Camarma de Esteruelas', 'Campo Real', 'Canencia', 'Carabaña', 'Casarrubuelos', 'Cenicientos', 'Cercedilla', 'Chapinería', 'Chinchón', 'Ciempozuelos', 'Cobeña', 'Collado Mediano', 'Collado Villalba', 'Colmenar Viejo', 'Colmenar de Oreja', 'Colmenar del Arroyo', 'Colmenarejo', 'Corpa', 'Coslada', 'Cubas de la Sagra', 'Daganzo de Arriba', 'El Atazar', 'El Berrueco', 'El Boalo - Cerceda – Mataelpino', 'El Escorial', 'El Molar (Madrid)', 'El Vellón', 'El Álamo', 'Estremera', 'Fresnedillas de la Oliva', 'Fresno de Torote', 'Fresno de Torote - Serracines', 'Fuenlabrada', 'Fuente El Saz de Jarama', 'Fuentidueña de Tajo', 'Galapagar', 'Garganta de los Montes', 'Gargantilla del Lozoya', 'Gascones', 'Getafe', 'Griñón', 'Guadalix de la Sierra', 'Guadarrama', 'Horcajo de la Sierra', 'Hoyo de Manzanares', 'Humanes de Madrid', 'La Cabrera', 'La Hiruela', 'Las Rozas de Madrid', 'Leganés', 'Loeches', 'Los Molinos', 'Los Santos de la Humosa', 'Lozoya', 'Lozoyuela-navas-sieteiglesias', 'Madarcos', 'Majadahonda', 'Manzanares El Real', 'Meco', 'Mejorada del Campo', 'Miraflores de la Sierra', 'Montejo de la Sierra', 'Moraleja de Enmedio', 'Moralzarzal', 'Morata de Tajuña', 'Móstoles', 'Navacerrada', 'Navalafuente', 'Navalagamella', 'Navalcarnero', 'Navarredonda', 'Navas del Rey', 'Nuevo Baztán', 'Orusco de Tajuña', 'Paracuellos de Jarama', 'Parla', 'Patones', 'Pedrezuela', 'Pelayos de la Presa', 'Perales de Tajuña', 'Pezuela de las Torres', 'Pinilla del Valle', 'Pinto', 'Piñuécar-gandullas', 'Pozuelo de Alarcón', 'Pozuelo del Rey', 'Puentes Viejas', 'Quijorna', 'Rascafría', 'Redueña', 'Ribatejada', 'Rivas-vaciamadrid', 'Robledo de Chavela', 'Robregordo', 'San Agustín del Guadalix', 'San Fernando de Henares', 'San Lorenzo de El Escorial', 'San Martín de Valdeiglesias', 'San Martín de la Vega', 'San Sebastián de los Reyes', 'Santa María de la Alameda', 'Santorcaz', 'Serranillos del Valle', 'Sevilla la Nueva', 'Soto del Real', 'Talamanca de Jarama', 'Tielmes', 'Titulcia', 'Torrejón de Ardoz', 'Torrejón de Velasco', 'Torrejón de la Calzada', 'Torrelaguna', 'Torrelodones', 'Torremocha de Jarama', 'Torres de la Alameda', 'Tres Cantos', 'Valdaracete', 'Valdeavero', 'Valdelaguna', 'Valdemanco', 'Valdemaqueda', 'Valdemorillo', 'Valdemoro', 'Valdeolmos-Alalpardo', 'Valdepiélagos', 'Valdetorres de Jarama', 'Valdilecha', 'Valverde de Alcalá', 'Velilla de San Antonio', 'Venturada', 'Villa del Prado', 'Villaconejos', 'Villalbilla', 'Villamanrique de Tajo', 'Villamanta', 'Villamantilla', 'Villanueva de Perales', 'Villanueva de la Cañada', 'Villanueva del Pardillo', 'Villar del Olmo', 'Villarejo de Salvanés', 'Villaviciosa de Odón', 'Villavieja del Lozoya', 'Zarzalejo']

# %% [markdown]
# #### Ejercicio 05. ¿El data set contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`true` o `fase`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO
validez = ds.isna().any(axis=1)
filas_con_nulos = ds[validez]


print(validez)
filas_con_nulos
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 15330    True
# 15331    True
# 15332    True
# 15333    True
# 15334    True
# Length: 15335, dtype: bool
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
#        phone_realEstate                                       url_inmueble  \
# 0           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 1           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 2           916350408.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3           916358736.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 4           912177526.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# ...                 ...                                                ...
# 15330       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15331       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15332       912780348.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15333       912788039.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 15334       911360461.0  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#        rooms  bathrooms  surface   price  ... level4Id level5Id level6Id  \
# 0        3.0        2.0    103.0  195000  ...        0        0        0
# 1        3.0        1.0      NaN   89000  ...        0        0        0
# 2        2.0        2.0     99.0  390000  ...        0        0        0
# 3        3.0        1.0     86.0   89000  ...        0        0        0
# 4        2.0        2.0    106.0  172000  ...        0        0        0
# ...      ...        ...      ...     ...  ...      ...      ...      ...
# 15330    2.0        1.0     96.0  259470  ...        0        0        0
# 15331    3.0        1.0    150.0  165000  ...        0        0        0
# 15332    4.0        2.0    175.0  495000  ...        0        0        0
# 15333    3.0        2.0    101.0  195000  ...        0        0        0
# 15334    3.0        2.0    152.0  765000  ...        0        0        0
#
#       level7Id level8Id accuracy          latitude          longitude zipCode  \
# 0            0        0        0  40,2948276786438  -3,44402412135624     NaN
# 1            0        0        1          40,28674           -3,79351     NaN
# 2            0        0        0  40,4115646786438  -3,90662252135624     NaN
# 3            0        0        0  40,2853785786438  -3,79508142135624     NaN
# 4            0        0        0  40,2998774864376  -3,45226301356237     NaN
# ...        ...      ...      ...               ...                ...     ...
# 15330        0        0        0          40,45416           -3,70286     NaN
# 15331        0        0        0          40,36652           -3,48951     NaN
# 15332        0        0        0          40,57444           -3,92124     NaN
# 15333        0        0        0          40,36967           -3,48105     NaN
# 15334        0        0        0          40,45773           -3,69068     NaN
#
#       customZone
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 15330        NaN
# 15331        NaN
# 15332        NaN
# 15333        NaN
# 15334        NaN
#
# [15335 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del data set, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO

data_set_sin_NA = ds.dropna(axis=0)


data_set_sin_NA
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id_realEstates, isNew, realEstate_name, phone_realEstate, url_inmueble, rooms, bathrooms, surface, price, date, description, address, country, level1, level2, level3, level4, level5, level6, level7, level8, upperLevel, countryId, level1Id, level2Id, level3Id, level4Id, level5Id, level6Id, level7Id, level8Id, accuracy, latitude, longitude, zipCode, customZone]
# Index: []
#
# [0 rows x 37 columns]

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido

# %%
# TODO

media_arroyomolinos = ds[ds["level5"] == "Arroyomolinos (Madrid)"]["price"].mean()
precio_formateado =  "{:,}".format(round(media_arroyomolinos, 0))

print(f"La media de precios de Arroyomolinos (Madrid) es {precio_formateado} $")
# Out:
# La media de precios de Arroyomolinos (Madrid) es 294,542.0 $

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
# TODO: Code
import matplotlib.pyplot as plt

precios_arroyomolino = ds[ds["level5"] == "Arroyomolinos (Madrid)"]["price"]


plt.hist(precios_arroyomolino, bins=20, color="blue")
plt.xlabel("Valores")
plt.ylabel("Frecuencia")
plt.title("Histograma de Precios de Arroyomolino (Madrid)")

lineas = [5, 10, 15, 20]
for y in lineas: 
    plt.axhline(y, color='grey', linestyle='dashed', linewidth=0.5)

plt.axvline(media_arroyomolinos, color='red', linestyle='dashed', linewidth=1)
plt.text((media_arroyomolinos + 0.1),5, f'Media Precios: {media_arroyomolinos:.2f}', rotation=90)


plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, has doble click en este celda y elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿ Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedio y escribe una conclusion acerca de ellos

# %%
# TODO
val_price = ds[ds["level5"] == "Valdemorillo"]["price"].mean()
gal_price = ds[ds["level5"] == "Galapagar"]["price"].mean()

val_price_form = "{:,}".format(round(val_price,2))
gal_price_form = "{:,}".format(round(gal_price,2))

print(f"{val_price_form} us$\n{gal_price_form} us$")


if val_price == gal_price:
    print("Los precios propedios de Valdemorillo y de Galapagar son los mismos")

else:
    print("Los precios promedio de Valdemorillo y de Galapagar son distintos")
# Out:
# 363,860.29 us$
# 360,063.2 us$
# Los precios promedio de Valdemorillo y de Galapagar son distintos

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (price/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio y escribe una conclusion acerca de ellos.
#
# Pista: Crea una nueva columna llamada `pps` (price per square) y luego analiza los valore.s

# %%
# TODO

ds["pps"] = ds["price"] / ds["surface"]

prom_m2_valdemo = ds[ds["level5"] == "Valdemorillo"]["pps"].mean()
prom_m2_gala = ds[ds["level5"] == "Galapagar"]["pps"].mean()

prom_m2_gala_form = "{:,}".format(round(prom_m2_gala, 2))
prom_m2_valdemo_form = "{:,}".format(round(prom_m2_valdemo, 2))

if prom_m2_gala == prom_m2_valdemo:
    print("Los precios por m2 de Valdemorillo y de Galapagar son", prom_m2_valdemo, "$ ambos")
else:
    print(f"Los precios por metro cuadraro de Valdemorillo son distintos. En valdemorillo el promedio por m2 es {prom_m2_valdemo_form} $ ,y en Galapagar, en cambio, es {prom_m2_gala_form} $")
# Out:
# Los precios por metro cuadraro de Valdemorillo son distintos. En valdemorillo el promedio por m2 es 1,317.95 $ ,y en Galapagar, en cambio, es 1,606.32 $

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusion al respecto.

# %%
# TODO: Código

new_ds = pd.DataFrame(ds[["pps", "price"]])
new_ds

med_pps = ds["pps"].mean()
med_pps_form = "{:,}".format(round(med_pps,2))

med_precios =ds['price'].mean()
med_precios_form = "{:,}".format(round(ds['price'].mean(),2))

plt.figure(figsize=(15,6))
plt.xlabel("Precio x 100.000 $")
plt.ylabel("Superficie en m2")
plt.axvline(med_precios,color='red', linestyle='dashed', linewidth=1)
plt.axhline(med_pps,color='red', linestyle='dashed', linewidth=1)
plt.text((med_precios + 10), 15000, f"Media precios =  {med_precios_form} $", rotation = 90)
plt.text(5000, med_pps, f"Media superficie =  {med_pps_form} m2")
plt.title("Relación entre el precio y la superficie")
plt.scatter(y=ds["pps"], x=ds["price"], s=1)
plt.show()

# %% [markdown]
# **TODO: Markdown**. Escribe aquí, haz doble click en este celda y elimina este contenido y reemplázalo por el texto que quires escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO

Ns_agencias = ds["realEstate_name"].nunique()
print(f"Hay {Ns_agencias} agencias de Bienes Raíses en el DataSet")
# Out:
# Hay 1821 agencias de Bienes Raíses en el DataSet

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

casas_x_pobl = ds["level5"].value_counts()

casas_x_pobl_N = casas_x_pobl.max()
poble = casas_x_pobl.idxmax()

print(f"La población que tiene más casas es{poble}. Hay {casas_x_pobl_N} en total.")
# Out:
# La población que tiene más casas es Madrid Capital. Hay 6643 en total.

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Has un subconjunto del Dataframe original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada","Leganés","Getafe","Alcorcón" (★★☆)
#
# Pista: Filtra el Dataframe original usando la columna `level5` y la función `isin`

# %%
# TODO

resumir_pobl = ["Fuenlabrada", "Getafe", "Leganés", "Alcorcón"]

sub_ds = ds[ds["level5"].isin(resumir_pobl)]

sub_ds
# Out:
#        Unnamed: 0  id_realEstates  isNew  \
# 1               2       153867863  False
# 3               4       152776331  False
# 85             86       153152077  False
# 94             95       153995577  False
# 109           110       153586414  False
# ...           ...             ...    ...
# 15275       15276       153903887  False
# 15291       15292       151697757  False
# 15305       15306       153902389  False
# 15322       15323       153871864  False
# 15325       15326       153901467  False
#
#                                  realEstate_name  phone_realEstate  \
# 1              tecnocasa fuenlabrada ferrocarril       916358736.0
# 3              tecnocasa fuenlabrada ferrocarril       916358736.0
# 85                       sinergical inmobiliaria               NaN
# 94                               viviendas365com       911226014.0
# 109              area uno asesores inmobiliarios       912664081.0
# ...                                          ...               ...
# 15275  aliseda servicios de gestion inmobiliaria       911368198.0
# 15291                                    unipiso       912788631.0
# 15305                             jadein ferrero       914871639.0
# 15322                          gestion comercial       911220662.0
# 15325                              montehogar 68       911790675.0
#
#                                             url_inmueble  rooms  bathrooms  \
# 1      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 3      https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 85     https://www.fotocasa.es/es/comprar/vivienda/le...    1.0        1.0
# 94     https://www.fotocasa.es/es/comprar/vivienda/le...    3.0        2.0
# 109    https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        3.0
# ...                                                  ...    ...        ...
# 15275  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        1.0
# 15291  https://www.fotocasa.es/es/comprar/vivienda/al...    3.0        2.0
# 15305  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        2.0
# 15322  https://www.fotocasa.es/es/comprar/vivienda/ma...    3.0        1.0
# 15325  https://www.fotocasa.es/es/comprar/vivienda/ma...    2.0        2.0
#
#        surface   price  ... level5Id level6Id level7Id level8Id accuracy  \
# 1          NaN   89000  ...        0        0        0        0        1
# 3         86.0   89000  ...        0        0        0        0        0
# 85        50.0  107000  ...        0        0        0        0        1
# 94       120.0  320000  ...        0        0        0        0        0
# 109      142.0  425000  ...        0        0        0        0        0
# ...        ...     ...  ...      ...      ...      ...      ...      ...
# 15275     78.0  138000  ...        0        0        0        0        1
# 15291    110.0  279000  ...        0        0        0        0        0
# 15305     85.0  170000  ...        0        0        0        0        0
# 15322     91.0  112000  ...        0        0        0        0        0
# 15325     99.0  215000  ...        0        0        0        0        1
#
#                latitude          longitude zipCode customZone          pps
# 1              40,28674           -3,79351     NaN        NaN          NaN
# 3      40,2853785786438  -3,79508142135624     NaN        NaN  1034.883721
# 85             40,35059           -3,82693     NaN        NaN  2140.000000
# 94             40,31933           -3,77574     NaN        NaN  2666.666667
# 109          40,3313411         -3,8313868     NaN        NaN  2992.957746
# ...                 ...                ...     ...        ...          ...
# 15275          40,31381           -3,83733     NaN        NaN  1769.230769
# 15291        40,3259051           -3,76318     NaN        NaN  2536.363636
# 15305        40,2882193         -3,8098617     NaN        NaN  2000.000000
# 15322          40,28282           -3,78892     NaN        NaN  1230.769231
# 15325          40,28062           -3,79869     NaN        NaN  2171.717172
#
# [907 rows x 38 columns]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barra de la media de los precios y explica lo que observas (debes usar el subconjunto obtenido de la pregunta 14) (★★★)
#
# Imprima un gráfico de barra de la media de precios y escriba en la celda Markdown un breve análisis del sector.

# %%
# TODO: Code
medias_precios = sub_ds.groupby("level5")["price"].mean()



plt.figure(figsize=(11,8))
medias_precios.plot(kind='bar', color= 'b')
plt.xlabel('Poblaciones')
plt.ylabel('Precio Medio')
plt.title('Precio Medio por Población')
plt.show()

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, has doble click en esta celda, elimina este contenido y coloca en su lugar el texto que quieres escribir. Luego, ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza dela muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Imprime ambos valores por  cada variable.

# %%
# TODO


variables = ["price", "surface", "rooms", "bathrooms"]
media_variables = sub_ds[variables].mean()
var_variables = sub_ds[variables].var()

print(media_variables)

print(var_variables)
# Out:
# price        223094.480706
# surface         111.752224
# rooms             3.017738
# bathrooms         1.633222
# dtype: float64
# price        1.492137e+10
# surface      4.263052e+03
# rooms        7.188859e-01
# bathrooms    5.717969e-01
# dtype: float64

# %%
# TODO
variables = ["price", "surface", "rooms", "bathrooms"]


def operaciones(value, nombre):
    mean = value.mean()
    varianza = value.var()

    return { 
        "Variable": nombre,
        "Media": mean,
        "Varianza" : varianza
        }

valores = []
for x in variables:
    valor = operaciones(sub_ds[x], x)
    valores.append(valor)



df_valores = pd.DataFrame(valores)
df_valores
# Out:
#     Variable          Media      Varianza
# 0      price  223094.480706  1.492137e+10
# 1    surface     111.752224  4.263052e+03
# 2      rooms       3.017738  7.188859e-01
# 3  bathrooms       1.633222  5.717969e-01

# %% [markdown]
# #### Exercise 17. What is the most expensive house of each population? You must use the subset obtained in the question 14 (★★☆)
#
# Print both the address and the price of the selected house of each population. You can print a DataFrame or a single line for each population

# %%
import timeit



id_casas = sub_ds.groupby("level5")["price"].idxmax()
sub_ds_max = sub_ds.loc[id_casas]

sub_ds_dic = sub_ds_max.to_dict(orient="records") #Es solo para probar un truquillo de optimización de código que vi en YouTube para no usar iterrows()

def opt_tiempo():
    
    for r in sub_ds_dic:
        
        population = r["level5"]
        price = "{:,}".format(r["price"])
        address = r["address"]
        
        print(f"En la población de {population}, la casa con el precio más alto tiene dirección en {address}, con un precio de ${price}")



timer = timeit.Timer(opt_tiempo)
tiempo = timer.timeit(1)

tiempo
# Out:
# En la población de Alcorcón, la casa con el precio más alto tiene dirección en Alcorcón, con un precio de $950,000
# En la población de Fuenlabrada, la casa con el precio más alto tiene dirección en Calle de Paulo Freire, 5, Fuenlabrada, con un precio de $490,000
# En la población de Getafe, la casa con el precio más alto tiene dirección en Getafe, con un precio de $1,050,000
# En la población de Leganés, la casa con el precio más alto tiene dirección en Avenida Reina Sofía, Leganés, con un precio de $650,000
# 8.683199848746881e-05

# %%
def met_iterrows():
    
    for i, r in sub_ds_max.iterrows():
      poblacion = r['level5']
      precio = r['price']
      direccion = r['address']
      print(f'En la población de {poblacion}, con direccion en {direccion}, se encuantra las casa más cara, con un precio de $ {precio}' )

timer = timeit.Timer(met_iterrows)
tiempo = timer.timeit(1)

tiempo
# Out:
# En la población de Alcorcón, con direccion en Alcorcón, se encuantra las casa más cara, con un precio de $ 950000
# En la población de Fuenlabrada, con direccion en Calle de Paulo Freire, 5, Fuenlabrada, se encuantra las casa más cara, con un precio de $ 490000
# En la población de Getafe, con direccion en Getafe, se encuantra las casa más cara, con un precio de $ 1050000
# En la población de Leganés, con direccion en Avenida Reina Sofía, Leganés, se encuantra las casa más cara, con un precio de $ 650000
# 0.001336372002697317

# %% [markdown]
# #### Exercise 18. Normalize the variable of prices for each population and plot the 4 histograms in the same plot (you must use the subset obtained in the question 14) (★★★)
#
# For the normalization method you can use the one you consider to, there is not a single correct answer to this question. Print the plot and write in the Markdown cell a brief analysis about the plot
#
# Hint: You can help yourself reviewing the multihist demo of Matplotlib

# %%
# TODO

# Normalización 
# Calculo la media y la desviación estándar por población
mean_prices = sub_ds.groupby('level5')['price'].mean()
std_prices = sub_ds.groupby('level5')['price'].std()

# Normalizo los precios por población
def normalize_prices(fila):
    mean_price = mean_prices[fila['level5']]
    std_price = std_prices[fila['level5']]
    normalized_price = (fila['price'] - mean_price) / std_price
    return normalized_price

sub_ds = sub_ds.copy()
sub_ds['precio_normalizado'] = sub_ds.apply(normalize_prices, axis=1)


l5_norm_prices = sub_ds.groupby("level5")

# %%
for poblacion, datos in l5_norm_prices:
    plt.figure(figsize=(10,5))
    plt.hist(datos, bins=20, alpha=0.7, color='skyblue', edgecolor= "black")
    plt.title(f"Histograma de Precios Normalizados para {poblacion}")
    plt.xlabel("Valores")
    plt.ylabel("Frecuencia")
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/matplotlib/axis.py:1769, in Axis.convert_units(self, x)
#    1768 try:
# -> 1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# The above exception was the direct cause of the following exception:
#
# ConversionError                           Traceback (most recent call last)
# Cell In[51], line 3
#       1 for poblacion, datos in l5_norm_prices:
#       2     plt.figure(figsize=(10,5))
# ----> 3     plt.hist(datos, bins=20, alpha=0.7, color='skyblue', edgecolor= "black")
#       4     plt.title(f"Histograma de Precios Normalizados para {poblacion}")
#       5     plt.xlabel("Valores")
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/pyplot.py:3236, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3211 @_copy_docstring_and_deprecators(Axes.hist)
#    3212 def hist(
#    3213     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3234     BarContainer | Polygon | list[BarContainer | Polygon],
#    3235 ]:
# -> 3236     return gca().hist(
#    3237         x,
#    3238         bins=bins,
#    3239         range=range,
#    3240         density=density,
#    3241         weights=weights,
#    3242         cumulative=cumulative,
#    3243         bottom=bottom,
#    3244         histtype=histtype,
#    3245         align=align,
#    3246         orientation=orientation,
#    3247         rwidth=rwidth,
#    3248         log=log,
#    3249         color=color,
#    3250         label=label,
#    3251         stacked=stacked,
#    3252         **({"data": data} if data is not None else {}),
#    3253         **kwargs,
#    3254     )
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6783, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6781 if orientation == "vertical":
#    6782     convert_units = self.convert_xunits
# -> 6783     x = [*self._process_unit_info([("x", x[0])], kwargs),
#    6784          *map(convert_units, x[1:])]
#    6785 else:  # horizontal
#    6786     convert_units = self.convert_yunits
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/artist.py:279, in Artist.convert_xunits(self, x)
#     277 if ax is None or ax.xaxis is None:
#     278     return x
# --> 279 return ax.xaxis.convert_units(x)
#
# File ~/.local/lib/python3.11/site-packages/matplotlib/axis.py:1771, in Axis.convert_units(self, x)
#    1769     ret = self.converter.convert(x, self.units, self)
#    1770 except Exception as e:
# -> 1771     raise munits.ConversionError('Failed to convert value(s) to axis '
#    1772                                  f'units: {x!r}') from e
#    1773 return ret
#
# ConversionError: Failed to convert value(s) to axis units: array(['sinergical inmobiliaria', 'area uno asesores inmobiliarios',
#        'raul', 'deplace', 'tecnocasa ciudad de alcorcon',
#        'grupo inmobiliario ares', 'grupo inmobiliario ares',
#        'altea machi bienes raices', 'grupo inmobiliario ares',
#        'tecnocasa mayesi', 'tecnocasa mayesi', 'particular', 'carlos',
#        'deplace', 'nozar sa', 'aedas homes', 'neopiso', 'altamira',
#        'urban alcorcon', 'nozar sa', 'vivantial', 'aedas homes',
#        'inmobiliaria de la rosa', 'grinval', 'inmobrain', 'elite',
#        'maria', 'sinergical inmobiliaria', 'ap inmobiliaria', 'elite',
#        'elite', 'elite', 'elite', 'elite',
#        'area uno asesores inmobiliarios',
#        'area uno asesores inmobiliarios',
#        'area uno asesores inmobiliarios',
#        'area uno asesores inmobiliarios',
#        'area uno asesores inmobiliarios',
#        'area uno asesores inmobiliarios',
#        'area uno asesores inmobiliarios',
#        'area uno asesores inmobiliarios', 'tiko', 'remax termes',
#        'inmobiliaria maqueda', 'redpiso alcorcon valderas',
#        'vivienda madrid usera plaza eliptica', 'inmobiliaria de la rosa',
#        'nozar sa', 'urban alcorcon', 'aedas homes', 'nozar sa',
#        'remax nuevo milenio', 'daurum estate', 'distrito 44',
#        'distrito 44', 'elite', 'r house ensanche sur',
#        'inmobiliaria maqueda', 'infocasa consulting',
#        'campuzano inmobiliaria', 'glomar alcorcon', 'glomar alcorcon',
#        'glomar alcorcon', 'glomar alcorcon', '100 home red inmobiliaria',
#        'glomar alcorcon', 'glomar alcorcon', 'inmobiliaria maqueda',
#        'arrenda', 'arrenda', 'bafre gestion y servicios inmobiliarios',
#        'vivantial', 'bafre gestion y servicios inmobiliarios',
#        'vivantial', 'comprarcasa montemi', 'inmobiliaria de la rosa',
#        'inmobiliaria de la rosa', '360 inmobiliaria', '360 inmobiliaria',
#        'nozar sa', 'vivantial', 'nozar sa', 'nozar sa',
#        'inmobiliaria de la rosa', 'nozar sa', 'avintia', 'vivantial',
#        'grupo tizona', 'deplace', 'inmobiliaria de la rosa',
#        'inmobiliaria de la rosa', 'inmobiliaria de la rosa', 'housell',
#        'nozar sa', 'tecnocasa trato inmobiliario alcorcon', 'elite',
#        'cerca servicios inmobiliarios', 'infocasa consulting', 'elite',
#        'elite', 'elite', 'soluciones inmobiliarias fergosa',
#        'soluciones inmobiliarias fergosa',
#        'soluciones inmobiliarias fergosa',
#        'soluciones inmobiliarias fergosa', 'savia inmobiliaria',
#        'savia inmobiliaria', 'century 21 about your house',
#        'ahora casa inmobiliaria', 'savia inmobiliaria',
#        'savia inmobiliaria', 'century 21 about your house',
#        'ahora casa inmobiliaria', 'nozar sa', 'nozar sa',
#        'soluciones inmobiliarias fergosa', 'avintia',
#        'inmobiliaria de la rosa', 'house things', 'daurum estate',
#        'inmobiliaria de la rosa', 'antonio', 'glomar alcorcon',
#        'glomar alcorcon', 'glomar alcorcon', 'glomar alcorcon', 'claudio',
#        'brisanya', 'habita mad', 'inmobiliaria de la rosa',
#        'inmobiliaria de la rosa', 'inmobiliaria de la rosa', 'laura',
#        'eduardo molet', 'altea machi bienes raices',
#        'altea machi bienes raices', 'grup inmobiliario mercurius',
#        'grupo tizona', 'inmobiliaria de la rosa', 'elite', 'elite',
#        'house and credit global solutions sl',
#        'house and credit global solutions sl',
#        'vitapiso servicios inmobiliarios', 'particular',
#        'infocasa consulting', 'tecnocasa ciudad de alcorcon',
#        'grupo inmobiliario ad', 'servihabitat servicios inmobiliarios',
#        'inmobiliaria de la rosa', 'outletdeviviendas', 'marcos',
#        'tecnocasa prado santo domingo', 'tecnocasa prado santo domingo',
#        'tecnocasa alcorcon oeste', 'sol inmobiliaria', 'piso al cuadrado',
#        'globalpiso alcorcon', 'n13 inmobiliaria', 'sudoeste viviendas',
#        'sudoeste viviendas', 'sudoeste viviendas', 'sudoeste viviendas',
#        'sudoeste viviendas', 'alvania', 'cr homes', 'deplace',
#        'altea machi bienes raices', 'altea machi bienes raices',
#        'altea machi bienes raices', 'altea machi bienes raices',
#        'altea machi bienes raices', 'avintia',
#        'soluciones inmobiliarias fergosa', 'oikos inmobiliaria',
#        'urbanissimo', 'inmobiliaria alpiso', 'grupo rein',
#        'vitapiso servicios inmobiliarios',
#        'vitapiso servicios inmobiliarios',
#        'vitapiso servicios inmobiliarios', 'bea', 'elite',
#        'soluciones inmobiliarias fergosa',
#        'soluciones inmobiliarias fergosa', 'oikos inmobiliaria',
#        'infocasa consulting', 'daurum estate', 'redpiso alcorcon sur'],
#       dtype=object)

# %%
media_precios = sub_ds.groupby("level5")["price"].mean()
media_precios["Alcorcón"]
# Out:
# 230071.05263157896

# %%
media_precios_dic = {"Alcorcón": 230071.052632,
                     "Fuenlabrada": 177198.021459,
                      "Getafe": 265040.500000,
                       "Leganés": 208682.010309  }


redo_values={}

for key, value in media_precios_dic.items():
   media_redo = round(value, 2)
   redo_values[key] = media_redo
   
print(redo_values)
# Out:
# {'Alcorcón': 230071.05, 'Fuenlabrada': 177198.02, 'Getafe': 265040.5, 'Leganés': 208682.01}

# %%
def normalize_prices(fila):

    normalized_price = (fila['price'] - mean_prices) / std_prices
   
    return normalized_price

# %%
from sklearn.preprocessing import MinMaxScaler


scaler = MinMaxScaler()


precios_normalizados = scaler.fit_transform(sub_ds['price'].values.reshape(-1, 1))

print(precios_normalizados)
# Out:
# [[0.0847619 ]
#  [0.0847619 ]
#  [0.10190476]
#  [0.3047619 ]
#  [0.4047619 ]
#  [0.22809524]
#  [0.27619048]
#  [0.05714286]
#  [0.13333333]
#  [0.1752381 ]
#  [0.15587619]
#  [0.17141905]
#  [0.13085714]
#  [0.12904762]
#  [0.15751333]
#  [0.09514286]
#  [0.24571429]
#  [0.13142857]
#  [0.37143238]
#  [0.23714286]
#  [0.43333333]
#  [0.16238095]
#  [0.15714286]
#  [0.11904762]
#  [0.16190476]
#  [0.1285619 ]
#  [0.12571429]
#  [0.09761905]
#  [0.16190476]
#  [0.40952381]
#  [0.2732381 ]
#  [0.15714286]
#  [0.11428571]
#  [0.35714286]
#  [0.15713333]
#  [0.22238095]
#  [0.24752381]
#  [0.45238095]
#  [0.09514286]
#  [0.11285714]
#  [0.10238095]
#  [0.11228571]
#  [0.23619048]
#  [0.35809524]
#  [0.13142857]
#  [0.37142857]
#  [0.46190476]
#  [0.36952381]
#  [0.2847619 ]
#  [0.11419048]
#  [0.12285714]
#  [0.09333333]
#  [0.11333333]
#  [0.15714286]
#  [0.09142857]
#  [0.238     ]
#  [0.15237143]
#  [0.12189524]
#  [0.13333333]
#  [0.11904762]
#  [0.31238095]
#  [0.15238095]
#  [0.27609524]
#  [0.13714286]
#  [0.22761905]
#  [0.13714286]
#  [0.13714286]
#  [0.22761905]
#  [0.13714286]
#  [0.        ]
#  [0.18095238]
#  [0.20761905]
#  [0.13047619]
#  [0.16761905]
#  [0.45238095]
#  [0.37143238]
#  [0.38095238]
#  [0.42857143]
#  [0.41704762]
#  [0.13428571]
#  [0.30449143]
#  [0.36628571]
#  [0.39047619]
#  [0.26095238]
#  [0.33047619]
#  [0.16190476]
#  [0.16190476]
#  [0.19047619]
#  [0.17142857]
#  [0.28095238]
#  [0.09047619]
#  [0.21052381]
#  [0.26657143]
#  [0.34190476]
#  [0.37619048]
#  [0.35238095]
#  [0.12466667]
#  [0.15428571]
#  [0.13428571]
#  [0.13809524]
#  [0.13333333]
#  [0.28447619]
#  [0.10466667]
#  [0.1       ]
#  [0.2352381 ]
#  [0.12238095]
#  [0.13142857]
#  [0.12952381]
#  [0.13047619]
#  [0.37143238]
#  [0.22857143]
#  [0.21619048]
#  [0.10466667]
#  [0.10476095]
#  [0.17428571]
#  [0.12857143]
#  [0.13809524]
#  [0.31428571]
#  [0.12190476]
#  [0.11674286]
#  [0.12857143]
#  [0.22085714]
#  [0.12095238]
#  [0.34761905]
#  [0.27094381]
#  [0.10857143]
#  [0.12190476]
#  [0.24742857]
#  [0.42571429]
#  [0.2047619 ]
#  [0.3392    ]
#  [0.39285714]
#  [0.31428571]
#  [0.16666667]
#  [0.30285714]
#  [0.2447619 ]
#  [0.08561905]
#  [0.37143238]
#  [0.13142857]
#  [0.13142857]
#  [0.26571429]
#  [0.16190476]
#  [0.10666667]
#  [0.2047619 ]]

# %% [markdown]
# **TODO: Markdown**. To write here, double click to this cell and just remove this content and place the text you want to write. Then, execute the cell.

# %% [markdown]
# #### Exercise 19. What can you say about the price per square meter (price/m2) between the towns of "Getafe" and "Alcorcón"? You must use the subset obtained in the question 14 (★★☆)
#
# Hint: Create a new column called `pps` (price per square) and then analyse the values

# %%
# TODO



sub_ds.iloc[:,1:]
pd.set_option('display.precision', 2)
pd.set_option('display.max_columns', None)

sub_ds.iloc[:,:].head()
# Out:
#      Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 1             2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 3             4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 85           86       153152077  False            sinergical inmobiliaria
# 94           95       153995577  False                    viviendas365com
# 109         110       153586414  False    area uno asesores inmobiliarios
#
#      phone_realEstate                                       url_inmueble  \
# 1            9.16e+08  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 3            9.16e+08  https://www.fotocasa.es/es/comprar/vivienda/ma...
# 85                NaN  https://www.fotocasa.es/es/comprar/vivienda/le...
# 94           9.11e+08  https://www.fotocasa.es/es/comprar/vivienda/le...
# 109          9.13e+08  https://www.fotocasa.es/es/comprar/vivienda/ma...
#
#      rooms  bathrooms  surface   price                          date  \
# 1      3.0        1.0      NaN   89000  2019-12-28T18:27:15.9975027Z
# 3      3.0        1.0     86.0   89000  2019-12-28T18:27:15.9975027Z
# 85     1.0        1.0     50.0  107000   2019-12-28T18:30:53.960102Z
# 94     3.0        2.0    120.0  320000   2019-12-28T18:30:53.960102Z
# 109    3.0        3.0    142.0  425000  2019-12-28T18:32:32.5337942Z
#
#                                            description  \
# 1    ""Agencia inmobiliaria de FUENLABRADA - zona F...
# 3    Agencia inmobiliaria de FUENLABRADA - zona Fue...
# 85   ¡oportunidad! vivienda de obra nueva, local ad...
# 94   VIVIENDAS365-VENDE- Hermosa Vivienda en el Bar...
# 109  AREA UNO asesores inmobiliarios oficina de las...
#
#                                  address country  level1  level2  \
# 1       Calle Polvoranca, 6, Fuenlabrada  España  Madrid  Madrid
# 3         Barrio San Andres, Fuenlabrada  España  Madrid  Madrid
# 85   Avenida Carabancheles, 18, Alcorcón  España  Madrid  Madrid
# 94            Avenida Los Pinos, Leganés  España  Madrid  Madrid
# 109                             Alcorcón  España  Madrid  Madrid
#
#                  level3                level4       level5 level6  \
# 1    Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada    NaN
# 3    Zona Sur de Madrid  Fuenlabrada, Zona de  Fuenlabrada    NaN
# 85        Zona Suroeste     Alcorcón, Zona de     Alcorcón    NaN
# 94   Zona Sur de Madrid      Leganés, Zona de      Leganés    NaN
# 109       Zona Suroeste     Alcorcón, Zona de     Alcorcón    NaN
#
#                                         level7         level8  \
# 1                                       Centro            NaN
# 3                                       Centro            NaN
# 85                                      Centro  Casco Antiguo
# 94   Valdepelayo - Montepinos - Arroyo Culebro            NaN
# 109             Prado Santo Domingo - Ensanche            NaN
#
#                                     upperLevel  countryId  level1Id  level2Id  \
# 1                                       Centro          0         0         0
# 3                                       Centro          0         0         0
# 85                               Casco Antiguo          0         0         0
# 94   Valdepelayo - Montepinos - Arroyo Culebro          0         0         0
# 109             Prado Santo Domingo - Ensanche          0         0         0
#
#      level3Id  level4Id  level5Id  level6Id  level7Id  level8Id  accuracy  \
# 1           0         0         0         0         0         0         1
# 3           0         0         0         0         0         0         0
# 85          0         0         0         0         0         0         1
# 94          0         0         0         0         0         0         0
# 109         0         0         0         0         0         0         0
#
#              latitude          longitude  zipCode  customZone      pps  \
# 1            40,28674           -3,79351      NaN         NaN      NaN
# 3    40,2853785786438  -3,79508142135624      NaN         NaN  1034.88
# 85           40,35059           -3,82693      NaN         NaN  2140.00
# 94           40,31933           -3,77574      NaN         NaN  2666.67
# 109        40,3313411         -3,8313868      NaN         NaN  2992.96
#
#      precio_normalizado
# 1                 -1.29
# 3                 -1.29
# 85                -0.97
# 94                 1.02
# 109                1.54

# %%
pps_Getafe = round(sub_ds[sub_ds["level5"] == "Getafe"]["pps"].mean(),2)
pps_Getafe
# Out:
# 2066.31

# %%
pobs = ["Getafe", "Alcorcón"]
res = []
for x in pobs:
    pps_mean = round(sub_ds[sub_ds["level5"] == x]["pps"].mean(),2)
    

print(res)
# Out:
# []

# %%
media_pps_dict = {x: round(sub_ds[sub_ds["level5"] == x]["pps"].mean(), 2) for x in pobs}

media_pps_df = pd.DataFrame(media_pps_dict, index = ["media de PPS"]).T

media_pps_df
# Out:
#           media de PPS
# Getafe         2066.31
# Alcorcón       2239.30

# %%
media_pps_dict = {x: round(sub_ds[sub_ds["level5"] == x]["pps"].mean(), 2) for x in pobs}

media_pps_df = pd.DataFrame(media_pps_dict.items(), columns=["Población", "Media de PPS"])

media_pps_df
# Out:
#   Población  Media de PPS
# 0    Getafe       2066.31
# 1  Alcorcón       2239.30

# %%
def analisis_pps(value, poblacion):
    mean = value.mean()
    varianza = value.var()
    desviacion = value.std()

    return { 
        "Población": poblacion,
                "Media": mean,
        "Varianza" : varianza,
        "Desviación" : desviacion
        }

valores = []
for x in pobs:
    valor = analisis_pps(sub_ds[sub_ds["level5"] == x]["pps"],x)
    valores.append(valor)



df_valores = pd.DataFrame(valores)
df_valores
# Out:
#   Población    Media   Varianza  Desviación
# 0    Getafe  2066.31  550375.11      741.87
# 1  Alcorcón  2239.30  291547.65      539.95

# %% [markdown]
# #### Exercise 20. Make the same plot for 4 different populations (level5 column) and rearrange them on the same graph? You must use the subset obtained in the question 14 (★★☆)
# Hint: make a scatter plot of each population using subplots.

# %%
# TODO

pobations = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]

fig, axs = plt.subplots(2, 2, figsize=(10, 10))


# Scatterplot para Fuenlabrada
axs[1, 0].scatter(x=sub_ds[sub_ds["level5"] == "Fuenlabrada"]["pps"], y=sub_ds[sub_ds["level5"] == "Fuenlabrada"]["price"])
axs[1, 0].set_title(f"Relación precio por mm2 para Fuenlabrada")
axs[1, 0].set_xlabel("Superficie en mm2")
axs[1, 0].set_ylabel("Precio")

# Scatterplot para Leganés
axs[0, 1].scatter(x=sub_ds[sub_ds["level5"] == "Leganés"]["pps"], y=sub_ds[sub_ds["level5"] == "Leganés"]["price"])
axs[0, 1].set_title(f"Relación precio por mm2 para Leganés")
axs[0, 1].set_xlabel("Superficie en mm2")
axs[0, 1].set_ylabel("Precio")

# Scatterplot para Getafe
axs[1, 1].scatter(x=sub_ds[sub_ds["level5"] == "Getafe"]["pps"], y=sub_ds[sub_ds["level5"] == "Getafe"]["price"])
axs[1, 1].set_title(f"Relación precio por mm2 para getafe")
axs[1, 1].set_xlabel("Superficie en mm2")
axs[1, 1].set_ylabel("Precio")

# Scatterplot para Getafe
axs[0, 0].scatter(x=sub_ds[sub_ds["level5"] == "Alcorcón"]["pps"], y=sub_ds[sub_ds["level5"] == "Alcorcón"]["price"])
axs[0, 0].set_title(f"Relación precio por mm2 para Alcorcón")
axs[0, 0].set_xlabel("Superficie en mm2")
axs[0, 0].set_ylabel("Precio")



plt.show()

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón ur de Madrid por color d cada población (debes usar el subconjunto obtenido en la pregunta 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar u código simple que transforme las columnas de coordenadas en un diccionario de python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, basemaps

# Mapa centrado en (60 grados latitud et -2.2 grados longitud)
# Latitud, longitud
map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20, 
    basemap=basemaps.Stamen.Terrain)
map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:44, in Bunch.__getattr__(self, key)
#      43 try:
# ---> 44     return self.__getitem__(key)
#      45 except KeyError as err:
#
# KeyError: 'Stamen'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 6
#       1 from ipyleaflet import Map, basemaps
#       3 # Mapa centrado en (60 grados latitud et -2.2 grados longitud)
#       4 # Latitud, longitud
#       5 map = Map(center = (60, -2.2), zoom = 2, min_zoom = 1, max_zoom = 20,
# ----> 6     basemap=basemaps.Stamen.Terrain)
#       7 map
#
# File ~/.local/lib/python3.11/site-packages/xyzservices/lib.py:46, in Bunch.__getattr__(self, key)
#      44     return self.__getitem__(key)
#      45 except KeyError as err:
# ---> 46     raise AttributeError(key) from err
#
# AttributeError: Stamen

# %%
## Aquí: traza la coordenadas de los estados

## PON TU CÓDIGO AQUÍ:
